# %%
def is_pangram(sentence):
    newsentence=sentence.lower()
    newsentence=sentence.replace(" ","")
    alphabet='abcdefghijklmnopqrstuvwxyz'
    print(len(alphabet))
    for i in range(len(sentence)):
        print('i is',i)
        for j in range(len(alphabet)-1):
            print('so j is',j)
            if(newsentence[i]==alphabet[j]):
                alphabet = alphabet.replace(alphabet[j],"")
                print('alphabet is',alphabet)
            elif(newsentence[i]!=alphabet[j]):
                print('sec alphabet is',alphabet)
            #print(len(alphabet))

# %%
is_pangram('The quick brown fox jumps over the lazy dog')
# Out:
# 26
# i is 0
# so j is 0
# sec alphabet is abcdefghijklmnopqrstuvwxyz
# so j is 1
# sec alphabet is abcdefghijklmnopqrstuvwxyz
# so j is 2
# sec alphabet is abcdefghijklmnopqrstuvwxyz
# so j is 3
# sec alphabet is abcdefghijklmnopqrstuvwxyz
# so j is 4
# sec alphabet is abcdefghijklmnopqrstuvwxyz
# so j is 5
# sec alphabet is abcdefghijklmnopqrstuvwxyz
# so j is 6
# sec alphabet is abcdefghijklmnopqrstuvwxyz
# so j is 7
# sec alphabet is abcdefghijklmnopqrstuvwxyz
# so j is 8
# sec alphabet is abcdefghijklmnopqrstuvwxyz
# so j is 9
# sec alphabet is abcdefghijklmnopqrstuvwxyz
# so j is 10
# sec alphabet is abcdefghijklmnopqrstuvwxyz
# so j is 11
# sec alphabet is abcdefghijklmnopqrstuvwxyz
# so j is 12
# sec alphabet is abcdefghijklmnopqrstuvwxyz
# so j is 13
# sec alphabet is abcdefghijklmnopqrstuvwxyz
# so j is 14
# sec alphabet is abcdefghijklmnopqrstuvwxyz
# so j is 15
# sec alphabet is abcdefghijklmnopqrstuvwxyz
# so j is 16
# sec alphabet is abcdefghijklmnopqrstuvwxyz
# ...

# %%
def is_pangram(sentence):
    ctr=0
    newsentence=sentence.lower()
    newsentence=sentence.replace(" ","")
    alphabet='abcdefghijklmnopqrstuvwxyz'
    for j in range(4):
        if(newsentence[j]=='h'):
            print(alphabet.replace("h",""))
        elif(newsentence[j]=='my'):
            print(alphabet.replace("y","replacedmy"))

# %%
is_pangram('himy')
# Out:
# abcdefgijklmnopqrstuvwxyz
