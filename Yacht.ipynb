# %%
# Score categories
# Change the values as you see fit
YACHT = 50
ONES = None
TWOS = None
THREES = None
FOURS = None
FIVES = None
SIXES = None
FULL_HOUSE = None
FOUR_OF_A_KIND = None
LITTLE_STRAIGHT = 30
BIG_STRAIGHT = 30
CHOICE = None


def score(dice, category):
    '''
    if(category == 'ONES'):
        count1 = 0
        for i in range(0,5):
            if(dice[i]==1):
                count1+=1
            else:
                count1 += 0
    print(count1)
    if(category == 'TWOS'):
        count2 = 0
        for i in range(0,5):
            if(dice[i]==2):
                count2+=1
            else:
                count2 += 0
    print(count2*2)
    if(category == 'THREES'):
        count3 = 0
        for i in range(0,5):
            if(dice[i]==3):
                count3+=1
            else:
                count3 += 0
    print(count3*3)
    if(category == 'FOURS'):
        count4 = 0
        for i in range(0,5):
            if(dice[i]==4):
                count4+=1
            else:
                count4 += 0
    print(count4*4)
    if(category == 'FIVES'):
        count5 = 0
        for i in range(0,5):
            if(dice[i]==5):
                count5+=1
            else:
                count5 += 0
    print(count5*5)
    if(category == 'SIXES'):
        count6 = 0
        for i in range(0,5):
            if(dice[i]==6):
                count6+=1
            ielse:
                count6 += 0
    print(count6*6)
    if(category == 'CHOICE'):
        count_ch = 0
        for i in range(0,5):
            count_ch = count_ch+dice[i]
    print(count_fh)
    if(category == 'LITTLE_STRAIGHT'):
        count_ls = 0
        for i in range(0,5):
            if(dice[i]<6):
                count_ls = count_ls+dice[i]
            else:
                count_ls = 0
    
        if(count_ls==15):
            print(30)
        else:
            print(0)
    if(category == 'BIG_STRAIGHT'):
        count_bs = 0
        for i in range(0,5):
            if(dice[i]>1):
                count_bs = count_bs+dice[i]
            else:
                count_bs = 0
    
        if(count_bs==20):
            print(30)
        else:
            print(0)
    if(category == 'YACHT'):
        count_yacht = 0
        if (len(set(dice)) == 1):
            print(50)
    '''
    if(category == 'YACHT'):
        count_yacht = 0
        if (len(set(dice)) == 1):
            print(50)

# %%
score([2,2,2,2,2],'YACHT')
# Out:
# 50

# %%
# Score categories
# Change the values as you see fit
YACHT = 50
ONES = None
TWOS = None
THREES = None
FOURS = None
FIVES = None
SIXES = None
FULL_HOUSE = None
FOUR_OF_A_KIND = None
LITTLE_STRAIGHT = 30
BIG_STRAIGHT = 30
CHOICE = None


def score(dice, category):
    if(category == 'ONES'):
        count1 = 0
        for i in range(0,5):
            if(dice[i]==1):
                count1+=1
            else:
                count1 += 0
        return(count1)
    elif(category == 'TWOS'):
        count2 = 0
        for i in range(0,5):
            if(dice[i]==2):
                count2+=1
            else:
                count2 += 0
        return(count2*2)
    elif(category == 'THREES'):
        count3 = 0
        for i in range(0,5):
            if(dice[i]==3):
                count3+=1
            else:
                count3 += 0
        return(count3*3)
    elif(category == 'FOURS'):
        count4 = 0
        for i in range(0,5):
            if(dice[i]==4):
                count4+=1
            else:
                count4 += 0
        return(count4*4)
    elif(category == 'FIVES'):
        count5 = 0
        for i in range(0,5):
            if(dice[i]==5):
                count5+=1
            else:
                count5 += 0
        return(count5*5)
    elif(category == 'SIXES'):
        count6 = 0
        for i in range(0,5):
            if(dice[i]==6):
                count6+=1
            else:
                count6 += 0
        return(count6*6)
    elif(category == 'CHOICE'):
        count_ch = 0
        for i in range(0,5):
            count_ch = count_ch+dice[i]
        return(count_fh)
    elif(category == 'LITTLE_STRAIGHT'):
        count_ls = 0
        for i in range(0,5):
            if(dice[i]<6):
                count_ls = count_ls+dice[i]
            else:
                count_ls = 0
    
        if(count_ls==15):
            return(30)
        else:
            return(0)
    elif(category == 'BIG_STRAIGHT'):
        count_bs = 0
        for i in range(0,5):
            if(dice[i]>1):
                count_bs = count_bs+dice[i]
            else:
                count_bs = 0
    
        if(count_bs==20):
            return(30)
        else:
            return(0)
    elif(category == 'YACHT'):
        count_yacht = 0
        if (len(set(dice)) == 1):
            return(50)
        else:
            return(0)
